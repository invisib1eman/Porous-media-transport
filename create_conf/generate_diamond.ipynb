# %%
import plotly.graph_objs as go
import numpy as np
def generate_diamond_lattice_points(size):
    sigma=1
    a=20*sigma/np.sqrt(3)
    lattice_points_a= []
    lattice_points_b=[]
    arm_a=[]
    arm_b=[]
    connection_a=[]
    connection_b=[]
    for x in range(size):
        for y in range(size):
            for z in range(size):
                lattice_points_a.append((x, y, z))
                lattice_points_a.append((x + 0.5*a, y + 0.5*a, z))
                lattice_points_a.append((x, y + 0.5*a, z + 0.5*a))
                lattice_points_a.append((x + 0.5*a, y, z + 0.5*a))
    for point in lattice_points_a:
        lattice_points_b.append([point[0]+0.25*a,point[1]+0.25*a,point[2]+0.25*a])
    for point in lattice_points_a:
        arm_a.append([point[0]+0.25*a/5,point[1]+0.25*a/5,point[2]+0.25*a/5])
        arm_a.append([point[0]-0.25*a/5,point[1]-0.25*a/5,point[2]+0.25*a/5])
        arm_a.append([point[0]-0.25*a/5,point[1]+0.25*a/5,point[2]-0.25*a/5])
        arm_a.append([point[0]+0.25*a/5,point[1]-0.25*a/5,point[2]-0.25*a/5])
        connection_a.append([point[0]+0.5*a/5,point[1]+0.5*a/5,point[2]+0.5*a/5])
        connection_a.append([point[0]-0.5*a/5,point[1]-0.5*a/5,point[2]+0.5*a/5])
        connection_a.append([point[0]-0.5*a/5,point[1]+0.5*a/5,point[2]-0.5*a/5])
        connection_a.append([point[0]+0.5*a/5,point[1]-0.5*a/5,point[2]-0.5*a/5])
    for point in lattice_points_b:
        arm_b.append([point[0]-0.25*a/5,point[1]-0.25*a/5,point[2]-0.25*a/5])
        arm_b.append([point[0]+0.25*a/5,point[1]+0.25*a/5,point[2]-0.25*a/5])
        arm_b.append([point[0]+0.25*a/5,point[1]-0.25*a/5,point[2]+0.25*a/5])
        arm_b.append([point[0]-0.25*a/5,point[1]+0.25*a/5,point[2]+0.25*a/5])
        connection_b.append([point[0]-0.5*a/5,point[1]-0.5*a/5,point[2]-0.5*a/5])
        connection_b.append([point[0]+0.5*a/5,point[1]+0.5*a/5,point[2]-0.5*a/5])
        connection_b.append([point[0]+0.5*a/5,point[1]-0.5*a/5,point[2]+0.5*a/5])
        connection_b.append([point[0]-0.5*a/5,point[1]+0.5*a/5,point[2]+0.5*a/5])
    return lattice_points_a,lattice_points_b,arm_a,arm_b,connection_a,connection_b

# Example usage:
size = 4  # Adjust the size as needed
polycentera,polycenterb,arm_a,arm_b,connection_a,connection_b = generate_diamond_lattice_points(size)


# Separate the coordinates into x, y, z arrays
x_coords, y_coords, z_coords = zip(*points)

# Create trace for scatter plot
trace = go.Scatter3d(
    x=x_coords,
    y=y_coords,
    z=z_coords,
    mode='markers',
    marker=dict(
        size=5,
        color='blue',                # Set color to blue
        opacity=0.8
    )
)

# Create layout for the plot
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X'),
        yaxis=dict(title='Y'),
        zaxis=dict(title='Z')
    ),
    title='Diamond Lattice Points'
)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Display the plot
fig.show()

# %%
import plotly.graph_objs as go
import numpy as np
def generate_diamond_lattice_points(size):
    sigma=1
    a=20*sigma/np.sqrt(3)
    lattice_points_a= []
    lattice_points_b=[]
    arm_a=[]
    arm_b=[]
    connection_a=[]
    connection_b=[]
    for x in range(size):
        for y in range(size):
            for z in range(size):
                lattice_points_a.append((x*a, y*a, z*a))
                lattice_points_a.append((x*a + 0.5*a, y*a + 0.5*a, z*a))
                lattice_points_a.append((x*a, y*a + 0.5*a, z*a + 0.5*a))
                lattice_points_a.append((x *a+ 0.5*a, y*a, z *a+ 0.5*a))
    for point in lattice_points_a:
        lattice_points_b.append([point[0]+0.25*a,point[1]+0.25*a,point[2]+0.25*a])
    for point in lattice_points_a:
        arm_a.append([point[0]+0.25*a/5,point[1]+0.25*a/5,point[2]+0.25*a/5])
        arm_a.append([point[0]-0.25*a/5,point[1]-0.25*a/5,point[2]+0.25*a/5])
        arm_a.append([point[0]-0.25*a/5,point[1]+0.25*a/5,point[2]-0.25*a/5])
        arm_a.append([point[0]+0.25*a/5,point[1]-0.25*a/5,point[2]-0.25*a/5])
        connection_a.append([point[0]+0.5*a/5,point[1]+0.5*a/5,point[2]+0.5*a/5])
        connection_a.append([point[0]-0.5*a/5,point[1]-0.5*a/5,point[2]+0.5*a/5])
        connection_a.append([point[0]-0.5*a/5,point[1]+0.5*a/5,point[2]-0.5*a/5])
        connection_a.append([point[0]+0.5*a/5,point[1]-0.5*a/5,point[2]-0.5*a/5])
    for point in lattice_points_b:
        arm_b.append([point[0]-0.25*a/5,point[1]-0.25*a/5,point[2]-0.25*a/5])
        arm_b.append([point[0]+0.25*a/5,point[1]+0.25*a/5,point[2]-0.25*a/5])
        arm_b.append([point[0]+0.25*a/5,point[1]-0.25*a/5,point[2]+0.25*a/5])
        arm_b.append([point[0]-0.25*a/5,point[1]+0.25*a/5,point[2]+0.25*a/5])
        connection_b.append([point[0]-0.5*a/5,point[1]-0.5*a/5,point[2]-0.5*a/5])
        connection_b.append([point[0]+0.5*a/5,point[1]+0.5*a/5,point[2]-0.5*a/5])
        connection_b.append([point[0]+0.5*a/5,point[1]-0.5*a/5,point[2]+0.5*a/5])
        connection_b.append([point[0]-0.5*a/5,point[1]+0.5*a/5,point[2]+0.5*a/5])
    return np.array(lattice_points_a),np.array(lattice_points_b),np.array(arm_a),np.array(arm_b),np.array(connection_a),np.array(connection_b)

# Example usage:
size = 4  # Adjust the size as needed
polycentera,polycenterb,arm_a,arm_b,connection_a,connection_b = generate_diamond_lattice_points(size)

# %%
type_a=connection_a
type_b=connection_b
num_charge=

# %%
points=np.concatenate((polycentera,polycenterb,arm_a,arm_b,connection_a,connection_b),axis=0)

# %%
with open("ion.data",'w') as f:
    f.write("LAMPPS data file\n")
    f.write("\n")
    f.write(f"{n_atoms} atoms\n")
    f.write(f"5 atoms\n")
    f.write(f"{n_bonds} bonds\n")
    f.write(f"2 bond types\n")
    f.write("\n")
    f.write("Masses\n")
    f.write("\n")
    for i in range(1,6):
        f.write(f"{i} 1\n")
    f.write("\n")
    f.write("Pair Coeffs")
    f.write("\n")
    for i in range(1,6):
        f.write(f"{i} 1 1\n")
    f.write("\n")
    f.write("Bond Coeffs")
    for i in range(1,3):
        f.write(f"{i} 30 1.5 1 1\n")
    f.write("\n")
    f.write("Atoms")
    f.write("\n")
    for i in range(0,n_atoms):
        f.write(f"{i} 30 1.5 1 1\n")
    f.write("\n")
    f.write("\n")
    f.write("Bonds")
    f.write("\n")
    for i in range(0,n_bonds):
        f.write(f"{i} 30 1.5 1 1\n")

# %%
# Separate the coordinates into x, y, z arrays
x_coords, y_coords, z_coords = zip(*points)

# Create trace for scatter plot
trace = go.Scatter3d(
    x=x_coords,
    y=y_coords,
    z=z_coords,
    mode='markers',
    marker=dict(
        size=5,
        color='blue',                # Set color to blue
        opacity=0.8
    )
)

# Create layout for the plot
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X'),
        yaxis=dict(title='Y'),
        zaxis=dict(title='Z')
    ),
    title='Diamond Lattice Points'
)

# Create figure
fig = go.Figure(data=[trace], layout=layout)

# Display the plot
fig.show()
